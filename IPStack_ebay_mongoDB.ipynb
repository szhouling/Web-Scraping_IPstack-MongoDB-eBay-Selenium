# %% [markdown]
# # Part 1

# %% [markdown]
# ### Database Programming: Write a simple program in Python that accomplishes the following:
# - Connects to local MongoDB instance.
# - Creates a database "msba"
# - Inserts the document {"ip": "192.168.1.1", "city": "Davis", "zip": "95616"} into a collection called "ip_addresses" within the "msba" database.

# %%
import pymongo
import bson

# %%
from pymongo import MongoClient

# Create a MongoClient to the running MongoDB instance
client = pymongo.MongoClient("mongodb://localhost:27017/")

# Create a new database
db = client['msba'] 

# Create a new collection
collection = db["ip_addresses"]

# New document to be inserted
new_ip_address = {"ip": "192.168.1.1", "city": "Davis", "zip": "95616"}

# Insert the new document into the collection
collection.insert_one(new_ip_address)
# Out:
# InsertOneResult(ObjectId('65f7345651e030496cc67fb9'), acknowledged=True)

# %% [markdown]
# ### API Call Program: Develop a program in Python that makes the five API calls described above and displays the results on the screen.

# %%
import requests
import time

# Function to get data from the IP address
def get_ip_data(ip_address, access_key):
    url = f"http://api.ipstack.com/{ip_address}?access_key={access_key}&output=json"
    response = requests.get(url)
    
    data = response.json()
    return data

my_ip = "" 
# List of IP addresses
ip_addresses = ["8.8.8.8", "128.120.0.25", "128.32.12.14", "64.165.72.144", my_ip]

# Loop through the list of IP addresses and print the fetched data
for ip in ip_addresses:
    ip_data = get_ip_data(ip, access_key)
    time.sleep(5)
    print(ip_data)
    print('-'*50)
# Out:
# {'ip': '8.8.8.8', 'type': 'ipv4', 'continent_code': 'NA', 'continent_name': 'North America', 'country_code': 'US', 'country_name': 'United States', 'region_code': 'OH', 'region_name': 'Ohio', 'city': 'Glenmont', 'zip': '44628', 'latitude': 40.5369987487793, 'longitude': -82.12859344482422, 'location': {'geoname_id': None, 'capital': 'Washington D.C.', 'languages': [{'code': 'en', 'name': 'English', 'native': 'English'}], 'country_flag': 'https://assets.ipstack.com/flags/us.svg', 'country_flag_emoji': '🇺🇸', 'country_flag_emoji_unicode': 'U+1F1FA U+1F1F8', 'calling_code': '1', 'is_eu': False}}
# --------------------------------------------------
# {'ip': '128.120.0.25', 'type': 'ipv4', 'continent_code': 'NA', 'continent_name': 'North America', 'country_code': 'US', 'country_name': 'United States', 'region_code': 'CA', 'region_name': 'California', 'city': 'Davis', 'zip': '95616', 'latitude': 38.56296157836914, 'longitude': -121.81600952148438, 'location': {'geoname_id': 5341704, 'capital': 'Washington D.C.', 'languages': [{'code': 'en', 'name': 'English', 'native': 'English'}], 'country_flag': 'https://assets.ipstack.com/flags/us.svg', 'country_flag_emoji': '🇺🇸', 'country_flag_emoji_unicode': 'U+1F1FA U+1F1F8', 'calling_code': '1', 'is_eu': False}}
# --------------------------------------------------
# {'ip': '128.32.12.14', 'type': 'ipv4', 'continent_code': 'NA', 'continent_name': 'North America', 'country_code': 'US', 'country_name': 'United States', 'region_code': 'CA', 'region_name': 'California', 'city': 'Berkeley', 'zip': '94705', 'latitude': 37.86159896850586, 'longitude': -122.24205017089844, 'location': {'geoname_id': 5327684, 'capital': 'Washington D.C.', 'languages': [{'code': 'en', 'name': 'English', 'native': 'English'}], 'country_flag': 'https://assets.ipstack.com/flags/us.svg', 'country_flag_emoji': '🇺🇸', 'country_flag_emoji_unicode': 'U+1F1FA U+1F1F8', 'calling_code': '1', 'is_eu': False}}
# --------------------------------------------------
# {'ip': '64.165.72.144', 'type': 'ipv4', 'continent_code': 'NA', 'continent_name': 'North America', 'country_code': 'US', 'country_name': 'United States', 'region_code': 'CA', 'region_name': 'California', 'city': 'Florin', 'zip': '95819', 'latitude': 38.57093048095703, 'longitude': -121.4357681274414, 'location': {'geoname_id': 5349613, 'capital': 'Washington D.C.', 'languages': [{'code': 'en', 'name': 'English', 'native': 'English'}], 'country_flag': 'https://assets.ipstack.com/flags/us.svg', 'country_flag_emoji': '🇺🇸', 'country_flag_emoji_unicode': 'U+1F1FA U+1F1F8', 'calling_code': '1', 'is_eu': False}}
# --------------------------------------------------
# {'ip': '192.168.177.47', 'type': 'ipv4', 'continent_code': None, 'continent_name': None, 'country_code': None, 'country_name': None, 'region_code': None, 'region_name': None, 'city': None, 'zip': None, 'latitude': 0.0, 'longitude': 0.0, 'location': {'geoname_id': None, 'capital': None, 'languages': None, 'country_flag': None, 'country_flag_emoji': None, 'country_flag_emoji_unicode': None, 'calling_code': None, 'is_eu': None}}
# --------------------------------------------------

# %% [markdown]
# ### JSON Parsing: Convert the JSON strings obtained into an internal Python object for further processing. Then, write code that iterates through the five API responses and prints the "city" and "zip" fields to the screen.

# %%
# Function to get data from the IP address
def get_ip_city_zip(ip_address, access_key):
    url = f"http://api.ipstack.com/{ip_address}?access_key={access_key}&output=json"
    response = requests.get(url)
    
    data = response.json()
    city = data.get('city', 'none')
    zip_code = data.get('zip', 'none')
    
    print(f"IP: {ip_address}")
    print(f"City: {city}")
    print(f"ZIP Code: {zip_code}")
    
access_key = ''
my_ip = ""
# List of IP addresses
ip_addresses = ["8.8.8.8", "128.120.0.25", "128.32.12.14", "64.165.72.144", my_ip]

# Loop through the list of IP addresses and print the fetched data
for ip in ip_addresses:
    get_ip_city_zip(ip, access_key)
    time.sleep(5)
    print('-'*50)
# Out:
# IP: 8.8.8.8
# City: Glenmont
# ZIP Code: 44628
# --------------------------------------------------
# IP: 128.120.0.25
# City: Davis
# ZIP Code: 95616
# --------------------------------------------------
# IP: 128.32.12.14
# City: Berkeley
# ZIP Code: 94705
# --------------------------------------------------
# IP: 64.165.72.144
# City: Florin
# ZIP Code: 95819
# --------------------------------------------------
# IP: 192.168.177.47
# City: None
# ZIP Code: None
# --------------------------------------------------

# %% [markdown]
# ### Data Storage Enhancemet:  Modify code from earlier step to also insert all five "ip", "city", and "zip" records into the "ip_addresses" collection created

# %%
# Function to get data from the IP address
collection = db["ip_addresses"]
def get_ip_city_zip_insert(ip_address, access_key):
    url = f"http://api.ipstack.com/{ip_address}?access_key={access_key}&output=json"
    response = requests.get(url)
    
    data = response.json()
    city = data.get('city', 'none')
    zip_code = data.get('zip', 'none')
    
    record = {
        "ip": ip_address,
        "city": city,
        "zip": zip_code
    }
    collection.insert_one(record)
    
my_ip = ""
# List of IP addresses
ip_addresses = ["8.8.8.8", "128.120.0.25", "128.32.12.14", "64.165.72.144", my_ip]

# Loop through the list of IP addresses and insert the fetched data
for ip in ip_addresses:
    get_ip_city_zip_insert(ip, access_key)
    time.sleep(5)

# %%
# Print the collection to check all documents
documents = collection.find()
for doc in documents:
    print(doc)
# Out:
# {'_id': ObjectId('65f624550cf7478eb7617935'), 'ip': '192.168.1.1', 'city': 'Davis', 'zip': '95616'}
# {'_id': ObjectId('65f63a420cf7478eb7617936'), 'ip': '8.8.8.8', 'city': 'Glenmont', 'zip': '44628'}
# {'_id': ObjectId('65f63a470cf7478eb7617937'), 'ip': '128.120.0.25', 'city': 'Davis', 'zip': '95616'}
# {'_id': ObjectId('65f63a4d0cf7478eb7617938'), 'ip': '128.32.12.14', 'city': 'Berkeley', 'zip': '94705'}
# {'_id': ObjectId('65f63a520cf7478eb7617939'), 'ip': '64.165.72.144', 'city': 'Florin', 'zip': '95819'}
# {'_id': ObjectId('65f7369a51e030496cc67fc3'), 'ip': '192.168.177.47', 'city': None, 'zip': None}

# %% [markdown]
# # Part 2

# %% [markdown]
# ### Automate Browser to Access eBay: Use Selenium in Python to launch a browser and navigate to https://www.ebay.com/.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Get on Google
driver = webdriver.Chrome()
time.sleep(4)
driver.get('https://www.ebay.com/')

# %% [markdown]
# ### Search for Items on eBay: Utilize Selenium in Python to perform a search for “Cell Phones” on eBay.

# %%
# Search on "askew"
time.sleep(1)
# Find the specific input where class name is gh-tb ui-autocomplete-input
input = driver.find_element(By.CSS_SELECTOR, '.gh-tb.ui-autocomplete-input')
input.send_keys('Cell Phones\n')

time.sleep(10)

# %% [markdown]
# ### Apply Filters: With the search results displayed, employ Selenium in Python to apply the following filters:
# -Network: Unlocked
# -Brand: LG
# -Screen Size: 6 in or More
# -Storage Capacity: 128 GB
# -Lock Status: Factory Unlocked
# -Condition: Used

# %%
# Select this specific class of spans which captures all the filters, and find the span which has the specific filters' text
unlocked = driver.find_element(By.XPATH, '//span[@class="cbx x-refine__multi-select-cbx" and text()="Unlocked"]')
unlocked.click()
time.sleep(3)

# %%
LG = driver.find_element(By.XPATH, '//span[@class="cbx x-refine__multi-select-cbx" and text()="LG"]')
LG.click()
time.sleep(3)

# %%
sreen_size = driver.find_element(By.XPATH, '//span[@class="cbx x-refine__multi-select-cbx" and text()="6 in or More"]')
sreen_size.click()
time.sleep(3)

# %%
storage = driver.find_element(By.XPATH, '//span[@class="cbx x-refine__multi-select-cbx" and text()="128 GB"]')
storage.click()
time.sleep(3)

# %%
lock_status = driver.find_element(By.XPATH, '//span[@class="cbx x-refine__multi-select-cbx" and text()="Factory Unlocked"]')
lock_status.click()
time.sleep(3)

# %%
Condition = driver.find_element(By.XPATH, '//span[@class="cbx x-refine__multi-select-cbx" and text()="Used"]')
Condition.click()
time.sleep(3)

# %% [markdown]
# ### Save Results Page: Use Selenium in Python to save the page, after filters have been applied, as “unlocked-lg-128gb-used.html” on your local filesystem.

# %%
import os
# Get the current directory of this jupyter book
current_working_directory = os.getcwd()
# Full path where the HTML file is
path = os.path.join(current_working_directory)

# %%
# Get the current URL
current_url = driver.current_url
driver.get(current_url)

# Get the HTML content
page_source = driver.page_source

# %%
current_working_directory = os.getcwd()
path = os.path.join(current_working_directory)
html_path = os.path.join(path, f"unlocked-lg-128gb-used.html")

# Write the content of content to the html file
with open(html_path, 'w', encoding='utf-8') as file:
    file.write(page_source)

# %% [markdown]
# ### Parse and Analyze Data: Open and parse the saved HTML file “unlocked-lg-128gb-used.html” using Python with BeautifulSoup with Jsoup.

# %% [markdown]
# ###  Extract and Print InformaƟon: For each item listed on the parsed page, extract and print-to-screen the following details:
#  Title
#  Seller
#  Seller ratng (percentage)
#  Price
#  Shipping information (if available)
#  Return information (if available)
#  Number of bids (if applicable)

# %%
from bs4 import BeautifulSoup

with open(html_path, 'r', encoding='utf-8') as file:
    html = file.read()
    soup = BeautifulSoup(html, 'html.parser')

# Find the ul class which contains all the listings
ul_element = soup.find('ul', class_='srp-results srp-list clearfix')

number_file = 0

if ul_element:
    # Use find_all to get all div elements with the class
    div_elements = ul_element.find_all('div', class_='s-item__wrapper clearfix')
    # Iterate through each div in the ul class to get information from each listing
    for div in div_elements:
        #Title
        title_span = div.find('span', role='heading')
        if title_span:
            title = title_span.get_text(strip=True)

        # Seller
        seller_span = div.find('span', class_ = 's-item__seller-info-text')
        if seller_span:
            seller_info = seller_span.get_text(strip = True)
            
            
        # Price
        price_span = div.find('span', class_ = 's-item__price')
        if price_span:
            price = price_span.get_text(strip = True)
        
        # Shipping info: some shipping info is in the span "POSITIVE BOLD", and some are just in normal font size
        shipping_bold = div.find('span', class_ = 'POSITIVE BOLD')
        if shipping_bold:
            shipping_info = shipping_bold.get_text(strip = True)
            
        shipping_normal = div.find('span', class_ = 's-item__shipping s-item__logisticsCost')
        if shipping_normal:
            shipping_info = shipping_normal.get_text(strip = True)
            
        # Return info: through investigating the webseit, returns are either free return or return not accepted 
        free_return = div.find('span', class_ = 's-item__free-returns s-item__freeReturnsNoFee')
        if free_return:
            return_info = free_return.get_text(strip = True)
        
        else :
            return_info = "Return not accepted"
        
        # Bids
        bid_span = div.find('span', class_ = 's-item__bids s-item__bidCount')
        if bid_span:
            bid_count = bid_span.get_text(strip = True)
        else: 
            bid_count = 'No bids yet'
            
        number_file += 1
        print(number_file)
        print("Title:", title)
        print("Seller and Seller rating: ", seller_info)
        print("Price: ", price)
        print("Shipping info: ", shipping_info)
        print("Return info: ", return_info)
        print("Bids count: ", bid_count)
        print('-'*60)
# Out:
# 1
# Title: LG Velvet 5G 128GB Grey LM-G900TM (T-Mobile Unlocked) Reduced Price zW7656
# Seller and Seller rating:  soonersoft (159,711) 98.8%
# Price:  $104.19
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 2
# Title: LG Velvet 5G - LM-G900VMP 128GB Gray Verizon + GSM Unlocked LTE Smartphone GREAT
# Seller and Seller rating:  discountphonedepot (4,270) 97.5%
# Price:  $116.73
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 3
# Title: LG Velvet 5G 128GB Gray LM-G900TM (Unlocked) - GSM World Phone - DV8150
# Seller and Seller rating:  soonersoft (159,711) 98.8%
# Price:  $119.68
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 4
# Title: LG K61 LG-Q630UM 128GB Unlocked White Android Smartphone
# Seller and Seller rating:  monkeytote (17,813) 98.5%
# Price:  $89.99
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 5
# Title: LG G8 Thinq - LM-G820 - 128GB - Black (T-Mobile - Password Locked)  (s11568)
# Seller and Seller rating:  katiesriches (265) 97.2%
# Price:  $30.00
# Shipping info:  +$6.15 shipping
# Return info:  Return not accepted
# Bids count:  0 bids·
# ------------------------------------------------------------
# 6
# Title: LG Velvet 5G LM-G900UM G900 (Unlocked) 128GB 6.8" - Excellent Condition
# Seller and Seller rating:  wikiwoo (38,790) 98.9%
# Price:  $124.95
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 7
# Title: LG Velvet 5G G900UM 128GB Aurora Silver 6.8" Screen (AT&T) -*Good**LGVelvet*LG98
# Seller and Seller rating:  cucoins88 (557) 99.6%
# Price:  $92.75
# Shipping info:  +$6.15 shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 8
# Title: Unlocked LG G8X ThinQ Dual Screen - 6.4" 128GB 6GB RAM - Perfect condition
# Seller and Seller rating:  orchid4139 (3) 100%
# Price:  $180.00
# Shipping info:  +$18.05 shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 9
# Title: LG RARE FLIP PHONE Ux280-WINE RED VINTAGE RETRO PURPLE US CELLULAR
# Seller and Seller rating:  theworldofstephjones (122) 100%
# Price:  $56.99
# Shipping info:  +$6.05 shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 10
# Title: LG G8 ThinQ - 128GB - Aurora Black (Unlocked) Grade C
# Seller and Seller rating:  bstco (42,809) 99.5%
# Price:  $74.99
# Shipping info:  Free 1-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 11
# Title: LG G8X ThinQ LM-G850 AT&T Only 128GB Black C Light Burn
# Seller and Seller rating:  yywirelesss (134,836) 98.2%
# Price:  $89.99
# Shipping info:  Free 2-3 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 12
# Title: USED - LG V30+ H930DS 128GB (FACTORY UNLOCKED) 6.0" 4GB RAM Raspberry Rose
# Seller and Seller rating:  never-msrp (126,758) 99.5%
# Price:  $129.99
# Shipping info:  Free shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 13
# Title: USED - LG V30+ H930DS 128GB (FACTORY UNLOCKED) 6.0" 4GB RAM Silver
# Seller and Seller rating:  never-msrp (126,758) 99.5%
# Price:  $124.99
# Shipping info:  Free shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 14
# Title: LG Velvet 5G 128GB Gray LM-G900TM (Unlocked) - GSM World Phone - DF8149
# Seller and Seller rating:  soonersoft (159,711) 98.8%
# Price:  $111.13
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 15
# Title: LG Velvet 5G VERIZON AT&T - 128GB Smartphone Aurora Gray / Silver  *Excellent*
# Seller and Seller rating:  wedeliverwireless (5,933) 98.5%
# Price:  $139.00
# Shipping info:  Free 1-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 16
# Title: LG G8X ThinQ LMG850UM9 128GB Black (Sprint T-Mobile AT&T) C GSM Unlocked
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $189.79
# Shipping info:  Free shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 17
# Title: LG G8 Thinq - LM-G820 - 128GB - Black (T-Mobile - Password Locked)  (s11568)
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $30.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 18
# Title: LG Velvet 5G LM-G900UM G900 (Unlocked) 128GB 6.8" - Excellent Condition
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $124.95
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 19
# Title: LG Velvet 5G 128GB Grey LM-G900TM (T-Mobile Unlocked) Reduced Price zW7656
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $104.19
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 20
# Title: LG Velvet 5G - LM-G900VMP 128GB Gray Verizon + GSM Unlocked LTE Smartphone GREAT
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $116.73
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 21
# Title: LG Velvet 5G G900UM 128GB Aurora Silver 6.8" Screen (AT&T) -*Good**LGVelvet*LG98
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $92.75
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 22
# Title: Unlocked LG G8X ThinQ Dual Screen - 6.4" 128GB 6GB RAM - Perfect condition
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $180.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 23
# Title: LG Velvet 5G G900UM 128GB Aurora Silver 6.8" Screen (AT&T) -Very Good*LG101
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $98.95
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 24
# Title: LG Velvet 5G 128GB Gray LM-G900TM (Unlocked) - GSM World Phone - DV8150
# Seller and Seller rating:  8ten1944 (194,788) 99.5%
# Price:  $119.68
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 25
# Title: LG G8X G850 128GB Black AT&T GSM Unlocked LCD Shadow Very Good
# Seller and Seller rating:  cellularstream (155,487) 98.5%
# Price:  $134.94
# Shipping info:  Free shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 26
# Title: Rooted LG G8 ThinQ Nethunter Pentest Hacker Phone Internal Monitor Mode H@cker
# Seller and Seller rating:  bar-5468 (41) 95.6%
# Price:  $250.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 27
# Title: USED - LG V30+ H930DS 128GB (FACTORY UNLOCKED) 6.0" 4GB RAM - Violet
# Seller and Seller rating:  never-msrp (126,758) 99.5%
# Price:  $134.99
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 28
# Title: [DHL Shipping]   LG Velvet2 Pro (LM-V700N)  collection  original box
# Seller and Seller rating:  piety11 (941) 97.5%
# Price:  $1,290.00
# Shipping info:  +$25.00 shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 29
# Title: LG alltel used phone
# Seller and Seller rating:  boughtnowcommerce (6,768) 99.9%
# Price:  $50.90
# Shipping info:  +$7.95 shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 30
# Title: LG Velvet 5G LM-G900 128GB Unlocked Android Smartphone | Excellent
# Seller and Seller rating:  miamiwireless (6,226) 98.7%
# Price:  $188.99
# Shipping info:  Free 1-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 31
# Title: LG Velvet 5G - Unlocked
# Seller and Seller rating:  williamr8810 (27) 0%
# Price:  $136.72
# Shipping info:  +$16.43 shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 32
# Title: LG G8 ThinQ Unlocked Verizon T-Mobile AT&T LMG820 128GB 4G+| Excellent
# Seller and Seller rating:  miamiwireless (6,226) 98.7%
# Price:  $139.99
# Shipping info:  Free 1-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 33
# Title: LG Velvet LM-G900N 6.8" OLED Display 4G/5G Factory Unlocked 8GB/128GB
# Seller and Seller rating:  with_us (17,723) 99%
# Price:  $308.51
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 34
# Title: LG V60 ThinQ 5G 128GB Classy Blue UNLOCKED T-Mobile NEEDS WORK READ DESCRIPTION
# Seller and Seller rating:  senorwillburr (127) 93.3%
# Price:  $249.00
# Shipping info:  +$6.15 shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 35
# Title: LG V40 ThinQ Original Unlocked V405UA V409N 6.4 Inches 64GB/128GB LTE Cellphone
# Seller and Seller rating:  bwop6402 (71) 96.1%
# Price:  $138.00to$170.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 36
# Title: Android LG G8X ThinQ LM-G850UM / LMG850EMW 4G LTE 6.4" 128GB 6GB RAM Phone
# Seller and Seller rating:  digital-home888 (8,458) 93.6%
# Price:  $166.28to$179.72
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 37
# Title: LG V50 ThinQ V500N V450PM Original Unlocked 6GB RAM 128GB ROM 16MP Cellphone
# Seller and Seller rating:  bwop6402 (71) 96.1%
# Price:  $176.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 38
# Title: LG V50 ThinQ V500N V450PM V450VM Original Unlocked 6GB+128GB ROM 16MP Smartphone
# Seller and Seller rating:  valueorder (13,580) 95.4%
# Price:  $155.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 39
# Title: LG V30 Original Unlocked 4GB RAM 64GB/128GB ROM 6.0 Inches 16.0MP LTE Cellphone
# Seller and Seller rating:  bwop6402 (71) 96.1%
# Price:  $120.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 40
# Title: LG V40 ThinQ Original Unlocked V405UA V409N 6.4 Inches 64GB/128GB LTE Cellphone
# Seller and Seller rating:  pyxp5717 (55) 95.1%
# Price:  $140.00to$172.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 41
# Title: LG Velvet 5G LM-G900 128GB, AT&T, Aurora Silver *Grade C*
# Seller and Seller rating:  wilzeecorp (75,720) 98.5%
# Price:  $155.95
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 42
# Title: 6.4'' LG V50 V500N V450PM ThinQ 5G LTE NFC Cell Phone 6GB+128GB SmartPhone
# Seller and Seller rating:  winwin2010 (19,080) 100%
# Price:  $199.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 43
# Title: 6.8'' LG VELVET G9 SmartPhone Screen Cell Phone Google Play Unlocked
# Seller and Seller rating:  winwin2010 (19,080) 100%
# Price:  $205.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 44
# Title: 6.4'' LG V40 ThinQ 4G LTE Cell Phone 6GB RAM 64GB ROM 16MP SmartPhone Unlocked
# Seller and Seller rating:  winwin2010 (19,080) 100%
# Price:  $145.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 45
# Title: LG G8 ThinQ 4G LTE Cell Phone Android 10.0 SmartPhone 6GB+128GB NFC Unlocked
# Seller and Seller rating:  winwin2010 (19,080) 100%
# Price:  $154.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 46
# Title: LG V50 ThinnQ 5G LM-V500V 6GB RAM (Unlocked) Smartphone - Black read desc.
# Seller and Seller rating:  anakinwalker (290) 100%
# Price:  $1,000.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 47
# Title: LG V60 ThinQ 5G Original 128GB ROM 64MP V600AM V600TM V600VM Unlocked Smartphone
# Seller and Seller rating:  pyxp5717 (55) 95.1%
# Price:  $232.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 48
# Title: LG VELVET G9 Original Unlocked 6.8'' NFC G900N G900VM 6GB+128GB 16MP SmartPhone
# Seller and Seller rating:  pyxp5717 (55) 95.1%
# Price:  $200.00to$202.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 49
# Title: 6.8'' LG V60 5G ThinQ Cell Phone Android SamrtPhone 8GB RAM 128GB ROM Phone
# Seller and Seller rating:  winwin2010 (19,080) 100%
# Price:  $225.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 50
# Title: LG V50 ThinQ 5G LM-V500N (Korea) LM-V450PM (Sprint) Android 16MPCell Phone 6.4"
# Seller and Seller rating:  tech-link-all (105) 100%
# Price:  $145.94
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 51
# Title: LG VELVET G9 Original Unlocked 6.8'' NFC G900N G900VM 6GB+128GB 16MP SmartPhone
# Seller and Seller rating:  bwop6402 (71) 96.1%
# Price:  $198.00to$200.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 52
# Title: LG Velvet 5G 128Gb Unlocked Fully Functional || With  shadow in screen
# Seller and Seller rating:  yzwireless (12,564) 96.1%
# Price:  $96.06
# Shipping info:  Free shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 53
# Title: LG V50 THINQ 5G V500N 6gb 128gb  Fingerprint Android 11 Dual Screen
# Seller and Seller rating:  salam-mobile (168) 94.4%
# Price:  $240.00
# Shipping info:  +$22.00 shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 54
# Title: LG Velvet 5G G900UM 128GB Aurora Silver 6.8" Screen (AT&T) -Very Good*LG101
# Seller and Seller rating:  cucoins88 (557) 99.6%
# Price:  $98.95
# Shipping info:  Free shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 55
# Title: USED - LG V30+ H930DS 128GB 4GB RAM (FACTORY UNLOCKED) 6.0" 16MP - Violet
# Seller and Seller rating:  never-msrp (126,758) 99.5%
# Price:  $134.99
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 56
# Title: USED - LG V30+ H930DS 128GB (FACTORY UNLOCKED) 4GB RAM -  6.0" 16MP - Black
# Seller and Seller rating:  never-msrp (126,758) 99.5%
# Price:  $134.99
# Shipping info:  Free 2-4 day shipping
# Return info:  Free returns
# Bids count:  No bids yet
# ------------------------------------------------------------
# 57
# Title: LG G8X ThinQ LM-G850UM / LMG850EMW 4G LTE 6.4" Android 128GB 6GB RAM Phone
# Seller and Seller rating:  phone360 (56) 93.3%
# Price:  $167.92to$181.65
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 58
# Title: LG G8X ThinQ LM-G850UM / LMG850EMW Android 4G LTE 6.4" 128GB 6GB RAM CellPhone
# Seller and Seller rating:  tech-link-all (105) 100%
# Price:  $167.81to$181.95
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 59
# Title: LG G8X ThinQ LM-G850UM / LMG850EMW Android 4G LTE 128GB 6GB RAM 6.4" CellPhone
# Seller and Seller rating:  utechmobile (60) 100%
# Price:  $170.37to$184.63
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 60
# Title: LG G8X ThinQ LM-G850UM / LMG850EMW Android 4G LTE 6.4" 128GB 6GB RAM Phone
# Seller and Seller rating:  top4easy (3,115) 98.1%
# Price:  $166.66to$180.99
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 61
# Title: 4G LTE LG G8X ThinQ LM-G850UM / LMG850EMW Android 128GB 6GB RAM 6.4" Phone
# Seller and Seller rating:  findsuperdeal (1,086) 92.9%
# Price:  $169.72to$184.01
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 62
# Title: Android LG G8X ThinQ LM-G850UM / LMG850EMW 6.4" 128GB 6GB RAM 4G LTE Phone
# Seller and Seller rating:  wireless-age (342) 90%
# Price:  $167.01to$181.11
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 63
# Title: LG G8X ThinQ LM-G850UM / LMG850EMW Android 6.4" 128GB 6GB RAM 4G LTE Phone
# Seller and Seller rating:  ubest-mobile-phone (61) 84%
# Price:  $167.82to$182.04
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 64
# Title: 4G LTE LG G8X ThinQ LM-G850UM / LMG850EMW Android 6.4" 128GB 6GB RAM Phone
# Seller and Seller rating:  lt-trading (1,093) 93.8%
# Price:  $167.31to$181.41
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 65
# Title: Android LG V50 ThinQ 5G LM-V500N (Korea) LM-V450PM (Sprint) 16MP Cell Phone 6.4"
# Seller and Seller rating:  ubest-mobile-phone (61) 84%
# Price:  $146.12
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 66
# Title: LG G8X ThinQ LM-G850UM / LMG850EMW Android 4G LTE 128GB 6GB RAM 6.4" Phone
# Seller and Seller rating:  cell-on-sale (2,567) 98.1%
# Price:  $166.72to$180.90
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 67
# Title: LG V50 ThinQ V500N V450PM Original Unlocked 6GB RAM 128GB ROM 16MP Cellphone
# Seller and Seller rating:  pyxp5717 (55) 95.1%
# Price:  $178.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------
# 68
# Title: LG V30 Original Unlocked 4GB RAM 64GB/128GB ROM 6.0 Inches 16.0MP LTE Cellphone
# Seller and Seller rating:  pyxp5717 (55) 95.1%
# Price:  $122.00
# Shipping info:  Free shipping
# Return info:  Return not accepted
# Bids count:  No bids yet
# ------------------------------------------------------------

# %%
driver.quit()
